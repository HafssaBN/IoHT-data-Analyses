# %%
from featuer_extraction import extract_features_from_info
import numpy as np
import pandas as pd

# %%
path_to_data = 'data/ECU_IoHT.xlsx'
data = pd.read_excel(path_to_data)

# %%
df=extract_features_from_info(data)

# %%
df
# Out:
#            No.          Time             Source        Destination Protocol  \
# 0            1      0.000000      Alfa_97:cf:63          Broadcast      ARP
# 1            2      0.002956  6e:c7:ec:3c:f2:ba      Alfa_97:cf:63      ARP
# 2            3      0.200725      Alfa_97:cf:63          Broadcast      ARP
# 3            4      0.202713     192.168.43.186       192.168.43.1      DNS
# 4            5      0.411565  6e:c7:ec:3c:f2:ba      Alfa_97:cf:63      ARP
# ...        ...           ...                ...                ...      ...
# 111202  111203  10103.029320      Alfa_97:cf:63  6e:c7:ec:3c:f2:ba      ARP
# 111203  111204  10103.140580  6e:c7:ec:3c:f2:ba      Alfa_97:cf:63      ARP
# 111204  111205  10103.383780      Alfa_97:cf:63          Broadcast      ARP
# 111205  111206  10106.386960      Alfa_97:cf:63          Broadcast      ARP
# 111206  111207  10109.390320      Alfa_97:cf:63          Broadcast      ARP
#
#         Length                                               Info    Type  \
# 0           42          Who has 192.168.43.1? Tell 192.168.43.186  Attack
# 1           42               192.168.43.1 is at 6e:c7:ec:3c:f2:ba  Attack
# 2           42          Who has 192.168.43.1? Tell 192.168.43.186  Attack
# 3           85  Standard query 0x0c44 PTR 1.43.168.192.in-addr...  Normal
# 4           42               192.168.43.1 is at 6e:c7:ec:3c:f2:ba  Attack
# ...        ...                                                ...     ...
# 111202      42          Who has 192.168.43.1? Tell 192.168.43.186  Attack
# 111203      42               192.168.43.1 is at 6e:c7:ec:3c:f2:ba  Attack
# 111204      42  192.168.43.1 is at 00:c0:ca:97:cf:63 (duplicat...  Attack
# 111205      42  192.168.43.1 is at 00:c0:ca:97:cf:63 (duplicat...  Attack
# 111206      42  192.168.43.1 is at 00:c0:ca:97:cf:63 (duplicat...  Attack
#
#        Type of attack  source_port  ...  tsecr  ws  urg  sack_perm  ttl  \
# 0        ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
# 1        ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
# 2        ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
# 3           No Attack          NaN  ...    NaN NaN  NaN        NaN  NaN
# 4        ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
# ...               ...          ...  ...    ...  ..  ...        ...  ...
# 111202   ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
# 111203   ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
# 111204   ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
# 111205   ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
# 111206   ARP Spoofing          NaN  ...    NaN NaN  NaN        NaN  NaN
#
#         seq_ack  ack_num    who_has_ip         tell_ip  \
# 0           NaN      NaN  192.168.43.1  192.168.43.186
# 1           NaN      NaN           NaN             NaN
# 2           NaN      NaN  192.168.43.1  192.168.43.186
# 3           NaN      NaN           NaN             NaN
# 4           NaN      NaN           NaN             NaN
# ...         ...      ...           ...             ...
# 111202      NaN      NaN  192.168.43.1  192.168.43.186
# 111203      NaN      NaN           NaN             NaN
# 111204      NaN      NaN           NaN             NaN
# 111205      NaN      NaN           NaN             NaN
# 111206      NaN      NaN           NaN             NaN
#
#                                              rest_of_info
# 0
# 1                    192.168.43.1 is at 6e:c7:ec:3c:f2:ba
# 2
# 3           Standard query  PTR 1.43.168.192.in-addr.arpa
# 4                    192.168.43.1 is at 6e:c7:ec:3c:f2:ba
# ...                                                   ...
# 111202
# 111203               192.168.43.1 is at 6e:c7:ec:3c:f2:ba
# 111204  192.168.43.1 is at 00:c0:ca:97:cf:63 (duplicat...
# 111205  192.168.43.1 is at 00:c0:ca:97:cf:63 (duplicat...
# 111206  192.168.43.1 is at 00:c0:ca:97:cf:63 (duplicat...
#
# [111207 rows x 28 columns]
